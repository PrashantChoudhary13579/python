# %% [markdown]
# # Setting spacing between subplots

# %% [markdown]
# Method 1: Using fig.tight_layout()
# Example 1 : tight_layout() without padding

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
fig, ax = plt.subplots(2,2,figsize = (8,8))

ax[0][0].plot(x,x)
ax[0][1].plot(x,x*2)
ax[1][0].plot(x,x*x)
ax[1][1].plot(x,x*x*x)

fig.tight_layout()
plt.show()

# %% [markdown]
# Example 2 : Using tight_layout by applying padding

# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
fig, aax = plt.subplots(2,2,figsize = (8,8))

aax[0,0].plot(x,x)
aax[0,1].plot(x,x*2)
aax[1,0].plot(x,x*x)
aax[1,1].plot(x,x*x*x)

aax[0,0].title.set_text("Linear")
aax[0,1].title.set_text("Double")
aax[1,0].title.set_text("Quadratic")
aax[1,1].title.set_text("Cubic")

fig.tight_layout(pad = 5.0)
plt.show()

# %% [markdown]
# Method 2: Using plt.subplots_adjust()

# %%
import numpy as np 
import matplotlib.pyplot as plt

# x = np.array([1,2,3,4,5])
x = np.linspace(0,10,100)
fig, ax = plt.subplots(2,2,figsize = (8,8))

ax[0,0].plot(x,x)
ax[0,1].plot(x,x* 2)
ax[1,0].plot(x,x*x)
ax[1,1].plot(x,x*x*x)

# Adjusting spacing
plt.subplots_adjust(left = 0.2,right = 0.8,top = 0.8, bottom = 0.2,wspace = 0.4,hspace = 0.4)
plt.show()

# %% [markdown]
# Method 3: Using constrained_layout = True to set spacing between subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
y = np.sin(x)

fig,ax = plt.subplots(2,2,constrained_layout = True)

ax[0,0].plot(x,x)
ax[0,1].plot(x,x*2)
ax[1,0].plot(x,x*x)
ax[1,1].plot(x,x*x*x)
plt.show()

# %% [markdown]
# Conclusion:
# 1. fig.tight_layout()
# 2. fig.tight_layout(pad =5.0)
# 3. plt.subplots_adust(left = ,right = ,top = , bottom= , wspace = , hspace = )
# 4. fig, ax = plt.subplots(2,2,constrained_layout = True)
